# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
requests.get(url + "&q=" + "Boston").json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 75.65,
#   'feels_like': 75.65,
#   'temp_min': 70.95,
#   'temp_max': 80.29,
#   'pressure': 1020,
#   'humidity': 58},
#  'visibility': 10000,
#  'wind': {'speed': 1.01, 'deg': 144, 'gust': 8.99},
#  'clouds': {'all': 0},
#  'dt': 1627138861,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1627118936,
#   'sunset': 1627171934},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date,
                          "description": city_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | pangnirtung
# Processing Record 5 of Set 1 | katobu
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | belaya gora
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | carauari
# Processing Record 10 of Set 1 | mokhsogollokh
# Processing Record 11 of Set 1 | kharitonovo
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | hurghada
# Processing Record 14 of Set 1 | ostersund
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | lengshuijiang
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | cedar falls
# Processing Record 20 of Set 1 | matay
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | changping
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | bulnes
# Processing Record 26 of Set 1 | ginda
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | ferrol
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | alofi
# Processing Record 31 of Set 1 | ambovombe
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | rawson
# Processing Record 34 of Set 1 | novonikolsk
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | kieta
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | oriximina
# Processing Record 40 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 1 | nerchinskiy zavod
# Processing Record 42 of Set 1 | mahibadhoo
# Processing Record 43 of Set 1 | bo rai
# Processing Record 44 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 1 | jiaocheng
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | tabialan
# City not found. Skipping...
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | aklavik
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | geraldton
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | virden
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | almaznyy
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | labuhan
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 2 | salamiyah
# Processing Record 18 of Set 2 | eyl
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | weligama
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | nuuk
# Processing Record 23 of Set 2 | kavieng
# Processing Record 24 of Set 2 | coquimbo
# Processing Record 25 of Set 2 | los llanos de aridane
# Processing Record 26 of Set 2 | palmer
# Processing Record 27 of Set 2 | gol
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | ostrovnoy
# Processing Record 30 of Set 2 | klaksvik
# Processing Record 31 of Set 2 | elizabeth city
# Processing Record 32 of Set 2 | port hedland
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | faanui
# Processing Record 35 of Set 2 | akyab
# Processing Record 36 of Set 2 | elva
# Processing Record 37 of Set 2 | caborca
# Processing Record 38 of Set 2 | belyy yar
# Processing Record 39 of Set 2 | ouadda
# Processing Record 40 of Set 2 | bilma
# Processing Record 41 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | andros town
# Processing Record 43 of Set 2 | borazjan
# Processing Record 44 of Set 2 | karakol
# Processing Record 45 of Set 2 | esperance
# Processing Record 46 of Set 2 | richards bay
# Processing Record 47 of Set 2 | mount isa
# Processing Record 48 of Set 2 | kankan
# Processing Record 49 of Set 2 | laguna
# Processing Record 50 of Set 2 | salvador
# Processing Record 1 of Set 3 | jiangyou
# Processing Record 2 of Set 3 | sao joao da barra
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | pangai
# Processing Record 5 of Set 3 | conde
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | paamiut
# Processing Record 8 of Set 3 | espanola
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | mackay
# Processing Record 12 of Set 3 | rincon
# Processing Record 13 of Set 3 | oranjestad
# Processing Record 14 of Set 3 | general nakar
# Processing Record 15 of Set 3 | auki
# Processing Record 16 of Set 3 | dubbo
# Processing Record 17 of Set 3 | ambilobe
# Processing Record 18 of Set 3 | corbelia
# Processing Record 19 of Set 3 | komsomolskiy
# Processing Record 20 of Set 3 | lasa
# Processing Record 21 of Set 3 | julio de castilhos
# Processing Record 22 of Set 3 | tommot
# Processing Record 23 of Set 3 | kununurra
# Processing Record 24 of Set 3 | san andres
# Processing Record 25 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 3 | beringovskiy
# Processing Record 27 of Set 3 | mezen
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | gazanjyk
# Processing Record 31 of Set 3 | tonshayevo
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | narrabri
# Processing Record 34 of Set 3 | cidreira
# Processing Record 35 of Set 3 | opoczno
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | arraial do cabo
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | sadri
# Processing Record 40 of Set 3 | kamenka
# Processing Record 41 of Set 3 | porbandar
# Processing Record 42 of Set 3 | iralaya
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | amga
# Processing Record 45 of Set 3 | amazar
# Processing Record 46 of Set 3 | qasigiannguit
# Processing Record 47 of Set 3 | leh
# Processing Record 48 of Set 3 | roald
# Processing Record 49 of Set 3 | ledyard
# Processing Record 50 of Set 3 | port lincoln
# Processing Record 1 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 4 | necochea
# Processing Record 3 of Set 4 | ouallam
# Processing Record 4 of Set 4 | pavino
# Processing Record 5 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 4 | cockburn town
# Processing Record 7 of Set 4 | san cristobal
# Processing Record 8 of Set 4 | gusinoye ozero
# Processing Record 9 of Set 4 | zapolyarnyy
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | gamba
# Processing Record 12 of Set 4 | siuri
# Processing Record 13 of Set 4 | new norfolk
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | port alberni
# Processing Record 17 of Set 4 | cangucu
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | meadow lake
# Processing Record 20 of Set 4 | xinqing
# Processing Record 21 of Set 4 | dryden
# Processing Record 22 of Set 4 | kutum
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | kruisfontein
# Processing Record 25 of Set 4 | makakilo city
# Processing Record 26 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | north myrtle beach
# Processing Record 29 of Set 4 | san pedro
# Processing Record 30 of Set 4 | yatou
# Processing Record 31 of Set 4 | raton
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | timizart
# Processing Record 34 of Set 4 | andenes
# Processing Record 35 of Set 4 | fallon
# Processing Record 36 of Set 4 | iqaluit
# Processing Record 37 of Set 4 | mount pleasant
# Processing Record 38 of Set 4 | dondo
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | tura
# Processing Record 41 of Set 4 | shawville
# Processing Record 42 of Set 4 | stromness
# Processing Record 43 of Set 4 | takoradi
# Processing Record 44 of Set 4 | perote
# Processing Record 45 of Set 4 | adrar
# Processing Record 46 of Set 4 | san jeronimo
# Processing Record 47 of Set 4 | yaransk
# Processing Record 48 of Set 4 | domoni
# Processing Record 49 of Set 4 | padre bernardo
# Processing Record 50 of Set 4 | clyde river
# Processing Record 1 of Set 5 | pisco
# Processing Record 2 of Set 5 | eldorado
# Processing Record 3 of Set 5 | pochutla
# Processing Record 4 of Set 5 | santo domingo
# Processing Record 5 of Set 5 | yichang
# Processing Record 6 of Set 5 | shenjiamen
# Processing Record 7 of Set 5 | zhigansk
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 10 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 5 | teya
# Processing Record 12 of Set 5 | egvekinot
# Processing Record 13 of Set 5 | pitimbu
# Processing Record 14 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 5 | charters towers
# Processing Record 16 of Set 5 | atuona
# Processing Record 17 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | zemio
# Processing Record 20 of Set 5 | denia
# Processing Record 21 of Set 5 | saint-philippe
# Processing Record 22 of Set 5 | guerrero negro
# Processing Record 23 of Set 5 | kodiak
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | viedma
# Processing Record 26 of Set 5 | asau
# Processing Record 27 of Set 5 | coihaique
# Processing Record 28 of Set 5 | kaeo
# Processing Record 29 of Set 5 | kenai
# Processing Record 30 of Set 5 | la rioja
# Processing Record 31 of Set 5 | severo-kurilsk
# Processing Record 32 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 5 | sabha
# Processing Record 34 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 5 | kaitangata
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 5 | kushima
# Processing Record 40 of Set 5 | saint george
# Processing Record 41 of Set 5 | lakes entrance
# Processing Record 42 of Set 5 | garden city
# Processing Record 43 of Set 5 | nagato
# Processing Record 44 of Set 5 | bontang
# Processing Record 45 of Set 5 | portpatrick
# City not found. Skipping...
# Processing Record 46 of Set 5 | bairiki
# Processing Record 47 of Set 5 | bulgan
# Processing Record 48 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 5 | kautokeino
# Processing Record 50 of Set 5 | cherskiy
# Processing Record 1 of Set 6 | chulym
# Processing Record 2 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 3 of Set 6 | fortuna
# Processing Record 4 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 5 of Set 6 | te anau
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | kungurtug
# Processing Record 8 of Set 6 | colon
# Processing Record 9 of Set 6 | cananea
# Processing Record 10 of Set 6 | diamantina
# Processing Record 11 of Set 6 | youkounkoun
# Processing Record 12 of Set 6 | provideniya
# Processing Record 13 of Set 6 | avera
# Processing Record 14 of Set 6 | parry sound
# Processing Record 15 of Set 6 | sungai besar
# Processing Record 16 of Set 6 | nanortalik
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | norman wells
# Processing Record 19 of Set 6 | college
# Processing Record 20 of Set 6 | najran
# Processing Record 21 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 22 of Set 6 | gangavalli
# Processing Record 23 of Set 6 | pamekasan
# Processing Record 24 of Set 6 | javanrud
# Processing Record 25 of Set 6 | quartucciu
# Processing Record 26 of Set 6 | kavaratti
# Processing Record 27 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 6 | huambo
# Processing Record 29 of Set 6 | pierre
# Processing Record 30 of Set 6 | gat
# Processing Record 31 of Set 6 | castro
# Processing Record 32 of Set 6 | eyrarbakki
# Processing Record 33 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 34 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 6 | vardo
# Processing Record 36 of Set 6 | jyvaskyla
# Processing Record 37 of Set 6 | damara
# Processing Record 38 of Set 6 | katha
# City not found. Skipping...
# Processing Record 39 of Set 6 | leningradskiy
# Processing Record 40 of Set 6 | shakawe
# Processing Record 41 of Set 6 | maceio
# Processing Record 42 of Set 6 | greencastle
# Processing Record 43 of Set 6 | katangli
# Processing Record 44 of Set 6 | high rock
# Processing Record 45 of Set 6 | hammerfest
# Processing Record 46 of Set 6 | saint-paul
# Processing Record 47 of Set 6 | karratha
# Processing Record 48 of Set 6 | isla mujeres
# Processing Record 49 of Set 6 | sydney
# Processing Record 50 of Set 6 | burica
# City not found. Skipping...
# Processing Record 1 of Set 7 | port hardy
# Processing Record 2 of Set 7 | norilsk
# Processing Record 3 of Set 7 | isangel
# Processing Record 4 of Set 7 | cabo san lucas
# Processing Record 5 of Set 7 | deputatskiy
# Processing Record 6 of Set 7 | severnyy
# Processing Record 7 of Set 7 | ushtobe
# Processing Record 8 of Set 7 | aykhal
# Processing Record 9 of Set 7 | namibe
# Processing Record 10 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 7 | cairns
# Processing Record 12 of Set 7 | faro
# Processing Record 13 of Set 7 | cayenne
# Processing Record 14 of Set 7 | usinsk
# Processing Record 15 of Set 7 | lavrentiya
# Processing Record 16 of Set 7 | lagoa
# Processing Record 17 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 7 | la ronge
# Processing Record 19 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 7 | blagoyevo
# Processing Record 21 of Set 7 | berezovka
# Processing Record 22 of Set 7 | taber
# Processing Record 23 of Set 7 | hami
# Processing Record 24 of Set 7 | xichang
# Processing Record 25 of Set 7 | bengkulu
# Processing Record 26 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 27 of Set 7 | iquique
# Processing Record 28 of Set 7 | matara
# Processing Record 29 of Set 7 | inuvik
# Processing Record 30 of Set 7 | seydi
# Processing Record 31 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 7 | griffith
# Processing Record 33 of Set 7 | lokomotivnyy
# Processing Record 34 of Set 7 | biak
# Processing Record 35 of Set 7 | ngunguru
# Processing Record 36 of Set 7 | ajdabiya
# Processing Record 37 of Set 7 | tuatapere
# Processing Record 38 of Set 7 | grindavik
# Processing Record 39 of Set 7 | tromso
# Processing Record 40 of Set 7 | chuy
# Processing Record 41 of Set 7 | pacific grove
# Processing Record 42 of Set 7 | san jose
# Processing Record 43 of Set 7 | ballina
# Processing Record 44 of Set 7 | pechora
# Processing Record 45 of Set 7 | les cayes
# Processing Record 46 of Set 7 | japura
# Processing Record 47 of Set 7 | harper
# Processing Record 48 of Set 7 | salta
# Processing Record 49 of Set 7 | nyurba
# Processing Record 50 of Set 7 | uige
# Processing Record 1 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 8 | mattawa
# Processing Record 3 of Set 8 | namie
# Processing Record 4 of Set 8 | bambous virieux
# Processing Record 5 of Set 8 | dali
# Processing Record 6 of Set 8 | henties bay
# Processing Record 7 of Set 8 | manacapuru
# Processing Record 8 of Set 8 | kashary
# Processing Record 9 of Set 8 | nola
# Processing Record 10 of Set 8 | dingle
# Processing Record 11 of Set 8 | imbituba
# Processing Record 12 of Set 8 | marienburg
# Processing Record 13 of Set 8 | maneromango
# Processing Record 14 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 8 | puerto ayacucho
# Processing Record 17 of Set 8 | hamilton
# Processing Record 18 of Set 8 | hambantota
# Processing Record 19 of Set 8 | peleduy
# Processing Record 20 of Set 8 | chokurdakh
# Processing Record 21 of Set 8 | rio gallegos
# Processing Record 22 of Set 8 | vuktyl
# Processing Record 23 of Set 8 | mayo
# Processing Record 24 of Set 8 | raduzhnyy
# Processing Record 25 of Set 8 | chapais
# Processing Record 26 of Set 8 | daru
# Processing Record 27 of Set 8 | bayshore gardens
# Processing Record 28 of Set 8 | naze
# Processing Record 29 of Set 8 | fort smith
# Processing Record 30 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 8 | ardahan
# Processing Record 32 of Set 8 | soyo
# Processing Record 33 of Set 8 | sabang
# Processing Record 34 of Set 8 | beloha
# Processing Record 35 of Set 8 | muisne
# Processing Record 36 of Set 8 | mizan teferi
# Processing Record 37 of Set 8 | namatanai
# Processing Record 38 of Set 8 | jinchang
# Processing Record 39 of Set 8 | kattivakkam
# Processing Record 40 of Set 8 | birao
# Processing Record 41 of Set 8 | senanga
# Processing Record 42 of Set 8 | rio grande
# Processing Record 43 of Set 8 | ossora
# Processing Record 44 of Set 8 | sakakah
# Processing Record 45 of Set 8 | juneau
# Processing Record 46 of Set 8 | korla
# Processing Record 47 of Set 8 | novoagansk
# Processing Record 48 of Set 8 | roebourne
# Processing Record 49 of Set 8 | aksarayskiy
# Processing Record 50 of Set 8 | salalah
# Processing Record 1 of Set 9 | waitati
# Processing Record 2 of Set 9 | flin flon
# Processing Record 3 of Set 9 | launceston
# Processing Record 4 of Set 9 | fukue
# Processing Record 5 of Set 9 | nemuro
# Processing Record 6 of Set 9 | bam
# Processing Record 7 of Set 9 | mangrol
# Processing Record 8 of Set 9 | yurimaguas
# Processing Record 9 of Set 9 | cuamba
# Processing Record 10 of Set 9 | miraflores
# Processing Record 11 of Set 9 | nome
# Processing Record 12 of Set 9 | constitucion
# Processing Record 13 of Set 9 | kirakira
# Processing Record 14 of Set 9 | ambanja
# Processing Record 15 of Set 9 | shangrao
# Processing Record 16 of Set 9 | karlskrona
# Processing Record 17 of Set 9 | neyshabur
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | tiksi
# Processing Record 20 of Set 9 | luena
# Processing Record 21 of Set 9 | hofn
# Processing Record 22 of Set 9 | oum hadjer
# Processing Record 23 of Set 9 | ust-maya
# Processing Record 24 of Set 9 | ottawa
# Processing Record 25 of Set 9 | broome
# Processing Record 26 of Set 9 | tres arroyos
# Processing Record 27 of Set 9 | itapage
# Processing Record 28 of Set 9 | moctezuma
# Processing Record 29 of Set 9 | sioux lookout
# Processing Record 30 of Set 9 | ginir
# Processing Record 31 of Set 9 | oromocto
# Processing Record 32 of Set 9 | sinnamary
# Processing Record 33 of Set 9 | abu road
# Processing Record 34 of Set 9 | great yarmouth
# Processing Record 35 of Set 9 | cervo
# Processing Record 36 of Set 9 | turukhansk
# Processing Record 37 of Set 9 | opuwo
# Processing Record 38 of Set 9 | manado
# Processing Record 39 of Set 9 | slave lake
# Processing Record 40 of Set 9 | mogadishu
# Processing Record 41 of Set 9 | westport
# Processing Record 42 of Set 9 | grand-santi
# Processing Record 43 of Set 9 | acapulco
# Processing Record 44 of Set 9 | meulaboh
# Processing Record 45 of Set 9 | fraserburgh
# Processing Record 46 of Set 9 | trincomalee
# Processing Record 47 of Set 9 | homer
# Processing Record 48 of Set 9 | katwijk
# Processing Record 49 of Set 9 | lompoc
# Processing Record 50 of Set 9 | fairview
# Processing Record 1 of Set 10 | pangody
# Processing Record 2 of Set 10 | vila franca do campo
# Processing Record 3 of Set 10 | kalmunai
# Processing Record 4 of Set 10 | axim
# Processing Record 5 of Set 10 | khandyga
# Processing Record 6 of Set 10 | the valley
# Processing Record 7 of Set 10 | sibolga
# Processing Record 8 of Set 10 | gohana
# Processing Record 9 of Set 10 | nalut
# Processing Record 10 of Set 10 | kawalu
# Processing Record 11 of Set 10 | acajutla
# Processing Record 12 of Set 10 | huaihua
# Processing Record 13 of Set 10 | clearwater
# Processing Record 14 of Set 10 | nastola
# Processing Record 15 of Set 10 | lappeenranta
# Processing Record 16 of Set 10 | puri
# Processing Record 17 of Set 10 | springfield
# Processing Record 18 of Set 10 | roblin
# Processing Record 19 of Set 10 | karasburg
# Processing Record 20 of Set 10 | reconquista
# Processing Record 21 of Set 10 | alugan
# Processing Record 22 of Set 10 | baiao
# Processing Record 23 of Set 10 | belmonte
# Processing Record 24 of Set 10 | bichena
# Processing Record 25 of Set 10 | olafsvik
# Processing Record 26 of Set 10 | camana
# Processing Record 27 of Set 10 | port keats
# Processing Record 28 of Set 10 | ofaqim
# Processing Record 29 of Set 10 | dayong
# Processing Record 30 of Set 10 | qui nhon
# Processing Record 31 of Set 10 | healdsburg
# Processing Record 32 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 10 | novyy urengoy
# Processing Record 34 of Set 10 | victoria
# Processing Record 35 of Set 10 | novochernorechenskiy
# Processing Record 36 of Set 10 | hasaki
# Processing Record 37 of Set 10 | verkhoyansk
# Processing Record 38 of Set 10 | dunmore town
# Processing Record 39 of Set 10 | new glasgow
# Processing Record 40 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 41 of Set 10 | lamar
# Processing Record 42 of Set 10 | jalu
# Processing Record 43 of Set 10 | port-gentil
# Processing Record 44 of Set 10 | troitskoye
# Processing Record 45 of Set 10 | ketchikan
# Processing Record 46 of Set 10 | weiser
# Processing Record 47 of Set 10 | neiafu
# Processing Record 48 of Set 10 | kenora
# Processing Record 49 of Set 10 | yemtsa
# Processing Record 50 of Set 10 | ostuacan
# Processing Record 1 of Set 11 | ponta delgada
# Processing Record 2 of Set 11 | bolshaya irba
# City not found. Skipping...
# Processing Record 3 of Set 11 | chernyshevskiy
# Processing Record 4 of Set 11 | saint-pierre
# Processing Record 5 of Set 11 | upernavik
# Processing Record 6 of Set 11 | hualmay
# Processing Record 7 of Set 11 | beihai
# Processing Record 8 of Set 11 | yenangyaung
# Processing Record 9 of Set 11 | republic
# Processing Record 10 of Set 11 | saint stephen
# Processing Record 11 of Set 11 | saldanha
# Processing Record 12 of Set 11 | walvis bay
# Processing Record 13 of Set 11 | ulaangom
# Processing Record 14 of Set 11 | narasannapeta
# Processing Record 15 of Set 11 | pimentel
# Processing Record 16 of Set 11 | bathsheba
# Processing Record 17 of Set 11 | mariel
# Processing Record 18 of Set 11 | yar-sale
# Processing Record 19 of Set 11 | calbuco
# Processing Record 20 of Set 11 | berezovyy
# Processing Record 21 of Set 11 | faya
# Processing Record 22 of Set 11 | marica
# Processing Record 23 of Set 11 | cruzeiro do sul
# Processing Record 24 of Set 11 | novolabinskaya
# Processing Record 25 of Set 11 | masterton
# Processing Record 26 of Set 11 | orangeburg
# Processing Record 27 of Set 11 | kharan
# Processing Record 28 of Set 11 | novobirilyussy
# Processing Record 29 of Set 11 | hovd
# Processing Record 30 of Set 11 | luang prabang
# Processing Record 31 of Set 11 | rochester
# Processing Record 32 of Set 11 | paralimni
# Processing Record 33 of Set 11 | chicomuselo
# Processing Record 34 of Set 11 | brookings
# Processing Record 35 of Set 11 | vila
# Processing Record 36 of Set 11 | point pleasant
# Processing Record 37 of Set 11 | denau
# City not found. Skipping...
# Processing Record 38 of Set 11 | baoding
# Processing Record 39 of Set 11 | acatlan
# Processing Record 40 of Set 11 | altus
# Processing Record 41 of Set 11 | padang
# Processing Record 42 of Set 11 | irtyshskiy
# Processing Record 43 of Set 11 | el tocuyo
# Processing Record 44 of Set 11 | karasjok
# Processing Record 45 of Set 11 | mersing
# Processing Record 46 of Set 11 | batemans bay
# Processing Record 47 of Set 11 | shingu
# Processing Record 48 of Set 11 | norrtalje
# Processing Record 49 of Set 11 | bom jesus da lapa
# Processing Record 50 of Set 11 | katrineholm
# Processing Record 1 of Set 12 | ust-kulom
# Processing Record 2 of Set 12 | martapura
# Processing Record 3 of Set 12 | tilichiki
# Processing Record 4 of Set 12 | cedar city
# Processing Record 5 of Set 12 | lewisporte
# Processing Record 6 of Set 12 | sao felix do xingu
# Processing Record 7 of Set 12 | linxia
# Processing Record 8 of Set 12 | pak phanang
# Processing Record 9 of Set 12 | seoul
# Processing Record 10 of Set 12 | tutoia
# Processing Record 11 of Set 12 | vrangel
# Processing Record 12 of Set 12 | zharkent
# Processing Record 13 of Set 12 | batagay
# Processing Record 14 of Set 12 | pangkalanbuun
# Processing Record 15 of Set 12 | barra do corda
# Processing Record 16 of Set 12 | santa isabel do rio negro
# Processing Record 17 of Set 12 | aswan
# Processing Record 18 of Set 12 | samagaltay
# Processing Record 19 of Set 12 | boyolangu
# Processing Record 20 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 12 | okhotsk
# Processing Record 22 of Set 12 | dibaya
# City not found. Skipping...
# Processing Record 23 of Set 12 | saint-augustin
# Processing Record 24 of Set 12 | broken hill
# Processing Record 25 of Set 12 | guane
# Processing Record 26 of Set 12 | krasnoselkup
# Processing Record 27 of Set 12 | meoqui
# Processing Record 28 of Set 12 | lata
# Processing Record 29 of Set 12 | novyy nekouz
# Processing Record 30 of Set 12 | chuzhou
# Processing Record 31 of Set 12 | lorengau
# Processing Record 32 of Set 12 | sambava
# Processing Record 33 of Set 12 | shelburne
# Processing Record 34 of Set 12 | rockhampton
# Processing Record 35 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 12 | ahipara
# Processing Record 37 of Set 12 | madaoua
# Processing Record 38 of Set 12 | demak
# Processing Record 39 of Set 12 | dunmore east
# Processing Record 40 of Set 12 | gorontalo
# Processing Record 41 of Set 12 | formosa
# Processing Record 42 of Set 12 | baruun-urt
# Processing Record 43 of Set 12 | cooma
# Processing Record 44 of Set 12 | skibbereen
# Processing Record 45 of Set 12 | nanzhang
# Processing Record 46 of Set 12 | ndele
# Processing Record 47 of Set 12 | weinan
# Processing Record 48 of Set 12 | cocentaina
# Processing Record 49 of Set 12 | san patricio
# Processing Record 50 of Set 12 | coulihaut
# City not found. Skipping...
# Processing Record 1 of Set 13 | vanavara
# Processing Record 2 of Set 13 | abu kamal
# Processing Record 3 of Set 13 | sur
# Processing Record 4 of Set 13 | sharlyk
# Processing Record 5 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 13 | nouadhibou
# Processing Record 7 of Set 13 | pasighat
# Processing Record 8 of Set 13 | hay river
# Processing Record 9 of Set 13 | sungaipenuh
# Processing Record 10 of Set 13 | chakulia
# Processing Record 11 of Set 13 | nantucket
# Processing Record 12 of Set 13 | celestun
# Processing Record 13 of Set 13 | yeppoon
# Processing Record 14 of Set 13 | marawi
# Processing Record 15 of Set 13 | port blair
# Processing Record 16 of Set 13 | rock sound
# Processing Record 17 of Set 13 | tougan
# Processing Record 18 of Set 13 | filadelfia
# Processing Record 19 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 13 | alyangula
# Processing Record 21 of Set 13 | san quintin
# Processing Record 22 of Set 13 | ilulissat
# Processing Record 23 of Set 13 | mendoza
# Processing Record 24 of Set 13 | sunamganj
# City not found. Skipping...
# Processing Record 25 of Set 13 | bennettsville
# Processing Record 26 of Set 13 | koungou
# Processing Record 27 of Set 13 | shepsi
# Processing Record 28 of Set 13 | grand gaube
# Processing Record 29 of Set 13 | wanning
# Processing Record 30 of Set 13 | aiquile
# Processing Record 31 of Set 13 | colgong
# Processing Record 32 of Set 13 | prado
# Processing Record 33 of Set 13 | vao
# Processing Record 34 of Set 13 | fereydunshahr
# Processing Record 35 of Set 13 | luanda
# Processing Record 36 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 13 | fort-de-france
# Processing Record 38 of Set 13 | ust-kuyga
# Processing Record 39 of Set 13 | todos santos
# Processing Record 40 of Set 13 | fort nelson
# Processing Record 41 of Set 13 | itarema
# Processing Record 42 of Set 13 | shalinskoye
# Processing Record 43 of Set 13 | aguimes
# Processing Record 44 of Set 13 | stade
# Processing Record 45 of Set 13 | saravan
# Processing Record 46 of Set 13 | baracoa
# Processing Record 47 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 48 of Set 13 | puro
# Processing Record 49 of Set 13 | jumla
# Processing Record 50 of Set 13 | khandbari
# Processing Record 1 of Set 14 | samarai
# Processing Record 2 of Set 14 | medvedka
# Processing Record 3 of Set 14 | jardim
# Processing Record 4 of Set 14 | callaguip
# Processing Record 5 of Set 14 | gotsu
# Processing Record 6 of Set 14 | tabas
# Processing Record 7 of Set 14 | vila do maio
# Processing Record 8 of Set 14 | atar
# Processing Record 9 of Set 14 | bauchi
# Processing Record 10 of Set 14 | pella
# Processing Record 11 of Set 14 | calvinia
# Processing Record 12 of Set 14 | paracuru
# Processing Record 13 of Set 14 | sitrah
# Processing Record 14 of Set 14 | ulety
# Processing Record 15 of Set 14 | prieska
# Processing Record 16 of Set 14 | kurilsk
# Processing Record 17 of Set 14 | ismailia
# Processing Record 18 of Set 14 | flinders
# Processing Record 19 of Set 14 | dawei
# Processing Record 20 of Set 14 | tayibe
# City not found. Skipping...
# Processing Record 21 of Set 14 | sovetskiy
# Processing Record 22 of Set 14 | longyan
# Processing Record 23 of Set 14 | dorfen
# Processing Record 24 of Set 14 | murray bridge
# Processing Record 25 of Set 14 | dungarvan
# Processing Record 26 of Set 14 | north bend
# Processing Record 27 of Set 14 | le port
# Processing Record 28 of Set 14 | jiwani
# Processing Record 29 of Set 14 | khani
# Processing Record 30 of Set 14 | santa rosa
# Processing Record 31 of Set 14 | port macquarie
# Processing Record 32 of Set 14 | alice springs
# Processing Record 33 of Set 14 | osmena
# Processing Record 34 of Set 14 | songjianghe
# Processing Record 35 of Set 14 | ucluelet
# Processing Record 36 of Set 14 | ust-tsilma
# Processing Record 37 of Set 14 | tiznit
# Processing Record 38 of Set 14 | praia da vitoria
# Processing Record 39 of Set 14 | sterling
# Processing Record 40 of Set 14 | coffs harbour
# Processing Record 41 of Set 14 | maniitsoq
# Processing Record 42 of Set 14 | zaysan
# Processing Record 43 of Set 14 | sistranda
# Processing Record 44 of Set 14 | strezhevoy
# Processing Record 45 of Set 14 | marion
# Processing Record 46 of Set 14 | lichinga
# Processing Record 47 of Set 14 | port shepstone
# Processing Record 48 of Set 14 | fuxin
# Processing Record 49 of Set 14 | samarinda
# Processing Record 50 of Set 14 | dhandhuka
# Processing Record 1 of Set 15 | kupang
# Processing Record 2 of Set 15 | troitsko-pechorsk
# Processing Record 3 of Set 15 | santa maria
# Processing Record 4 of Set 15 | tsovagyugh
# Processing Record 5 of Set 15 | yulara
# Processing Record 6 of Set 15 | eastlake
# Processing Record 7 of Set 15 | sonepur
# Processing Record 8 of Set 15 | sao miguel do araguaia
# Processing Record 9 of Set 15 | duz
# City not found. Skipping...
# Processing Record 10 of Set 15 | pilar
# Processing Record 11 of Set 15 | teonthar
# Processing Record 12 of Set 15 | payo
# Processing Record 13 of Set 15 | goianesia
# Processing Record 14 of Set 15 | steyregg
# Processing Record 15 of Set 15 | senno
# Processing Record 16 of Set 15 | staryy nadym
# Processing Record 17 of Set 15 | mosetse
# Processing Record 18 of Set 15 | severnoye
# Processing Record 19 of Set 15 | vilhena
# Processing Record 20 of Set 15 | berlevag
# Processing Record 21 of Set 15 | vredendal
# Processing Record 22 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 15 | methven
# Processing Record 24 of Set 15 | kinsale
# Processing Record 25 of Set 15 | george
# Processing Record 26 of Set 15 | derzhavinsk
# Processing Record 27 of Set 15 | irati
# Processing Record 28 of Set 15 | antofagasta
# Processing Record 29 of Set 15 | ghanzi
# Processing Record 30 of Set 15 | boa vista
# Processing Record 31 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 15 | namikupa
# Processing Record 33 of Set 15 | cukai
# Processing Record 34 of Set 15 | luangwa
# Processing Record 35 of Set 15 | palmas
# Processing Record 36 of Set 15 | manoel urbano
# Processing Record 37 of Set 15 | yerbogachen
# Processing Record 38 of Set 15 | jacareacanga
# Processing Record 39 of Set 15 | takaka
# Processing Record 40 of Set 15 | manggar
# Processing Record 41 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 15 | buluang
# Processing Record 43 of Set 15 | hobyo
# Processing Record 44 of Set 15 | waddan
# Processing Record 45 of Set 15 | sisimiut
# Processing Record 46 of Set 15 | petropavlovka
# Processing Record 47 of Set 15 | santa cruz
# Processing Record 48 of Set 15 | merke
# Processing Record 49 of Set 15 | peniche
# Processing Record 50 of Set 15 | aviles
# Processing Record 1 of Set 16 | mangla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Cape Town -33.9258   18.4232     65.26        35           0        5.75
# 1    Mahebourg -20.4081   57.7000     70.09        73          20        9.22
# 2      Mataura -46.1927  168.8643     39.47        91          90        3.67
# 3  Pangnirtung  66.1451  -65.7125     46.40        71          90        5.75
# 4       Katobu  -4.9408  122.5276     71.28        91          19        3.24
#
#   Country      description
# 0      ZA        clear sky
# 1      MU       few clouds
# 2      NZ  overcast clouds
# 3      CA  overcast clouds
# 4      ID       few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
